# %% [markdown]
# Tecnica en la que el workflow o proceso uarda el progreso a un determinado momento, permitiendo pausarlo y retomarlo justo donde lo dejo

# %% [markdown]
# Lo que se debe hacer es:
# - especificar el checkpointer donde se guardara
# - Especificar el thread
# - Encerrar dentro del decorator @task todas los pasos que no sean deterministicos (RNG por ejemplo) u operaciones con efectos secundarios (creo un archivo)
#
# Lo que ocurre es que no retoma el codigo en la línea donde lo dejo; identifica un starting point apropiado para retomar donde lo dejo, repitiendo steps.
